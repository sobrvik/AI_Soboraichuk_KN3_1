# %% [markdown]
# <a href="https://colab.research.google.com/github/sobrvik/AI_Soboraichuk_KN3_1/blob/main/practicals/practical_2/Practical_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url)

print("Перші рядки датасету:")
print(df.head())

print("\nПропущені значення:")
print(df.isnull().sum())

median_age = df['Age'].median()
df['Age'] = df['Age'].fillna(median_age)

df = df.drop(['Name','Ticket','Cabin','PassengerId'], axis=1)

print("\nВиживання за статтю:")
print(df.groupby('Sex')['Survived'].mean())

sns.barplot(x='Pclass', y='Survived', data=df)
plt.title("Виживання залежно від класу")
plt.show()

gender_map = {'male':0,'female':1}
df['Sex'] = df['Sex'].map(gender_map)

df = df.dropna(subset=['Embarked'])

ports_map = {'S':0,'C':1,'Q':2}
df['Embarked'] = df['Embarked'].map(ports_map)

print("\nДані готові до аналізу")

###  DZ new passenger

new_passenger = pd.DataFrame({
    'Pclass':[1],
    'Sex':[0],
    'Age':[25],
    'SibSp':[0],
    'Parch':[0],
    'Fare':[100],
    'Embarked':[0]
})
# Out:
# Перші рядки датасету:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...
